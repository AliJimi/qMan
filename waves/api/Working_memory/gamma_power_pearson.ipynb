# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as ss

frontal_low=np.array([
1.5964,
7.0344,
6.8561,
7.0157,
8.0588,
9.0029,
7.1686,
6.5915,
8.6222,
7.6327,
9.2393,
7.1730,
8.3499,
6.6764,
8.3228,
7.5050,
7.3739,
7.7176,
7.4095,
7.4258,
7.2308,
7.7748,
7.3488,
9.1887])

parietal_low=np.array([
7.8416,
7.6933,
6.5121,
7.0507,
7.8682,
7.9239,
7.7308,
6.5505,
8.8615,
7.5311,
8.7683,
6.9044,
7.3868,
6.7590,
8.0941,
7.6998,
6.9701,
8.2330,
5.8519,
6.7290,
6.0236,
7.9985,
7.4148,
9.6324])

frontal_high=np.array([
1.3831,
6.8924,
6.5556,
6.8607,
7.9292,
8.9081,
7.2048,
6.3306,
8.3060,
8.0201,
9.1182,
6.7777,
8.0148,
6.2890,
7.9764,
7.3901,
6.8099,
7.4105,
7.2884,
7.3529,
6.8651,
7.4232,
7.0108,
8.9011])

parietal_high=np.array([
7.5124,
7.3708,
6.1041,
6.6902,
7.7071,
7.7813,
7.5464,
6.1358,
8.5095,
7.8970,
8.5851,
6.3623,
7.0284,
6.3970,
7.7628,
7.3750,
6.4021,
7.8705,
5.3088,
6.8815,
5.4787,
7.7272,
7.0649,
9.3131])

ng_score=np.array([
5,
1.5,
3.5,
4.9,
1,
3.6,
5,
2,
5,
2.1,
3.1,
1.7,
4,
1,
4,
2.6,
1,
1.7,
1,
2.6,
3.5,
1,
2.5,
1])


h1=scipy.stats.pearsonr(frontal_low, ng_score)   
h2=scipy.stats.pearsonr(parietal_low, ng_score)   
h3=scipy.stats.pearsonr(frontal_high, ng_score)   
h4=scipy.stats.pearsonr(parietal_high, ng_score)   


print(h1)
print(h2)
print(h3)
print(h4)
# Out:
# (-0.21974171812887927, 0.3022026285024745)
# (0.10798425594138879, 0.6154953167008808)
# (-0.19872083098858614, 0.35191083468070594)
# (0.11302721574768503, 0.5989933474064134)
