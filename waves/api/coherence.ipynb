# %%
from neurodsp.utils.download import load_ndsp_data
import numpy as np
import scipy.io
import scipy.signal as signal
data = load_ndsp_data('D:\\jupyter_folder\\nurun_python_codes\\pre_Sb.npy')
# Set sampling rate, and create a times vector for plotting
fs = 250

# %%
gg,coherence1=signal.coherence(data[1,:], data[3,:], fs, window='hann', nperseg=256, noverlap=None, nfft=None, detrend='constant', axis=-1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2d2cf79b94f4> in <module>
# ----> 1 gg,coherence1=signal.coherence(data[1,:], data[3,:], fs, window='hann', nperseg=256, noverlap=None, nfft=None, detrend='constant', axis=-1)
#
# NameError: name 'signal' is not defined

# %%
coherence
# Out:
# (array([  0.       ,   0.9765625,   1.953125 ,   2.9296875,   3.90625  ,
#           4.8828125,   5.859375 ,   6.8359375,   7.8125   ,   8.7890625,
#           9.765625 ,  10.7421875,  11.71875  ,  12.6953125,  13.671875 ,
#          14.6484375,  15.625    ,  16.6015625,  17.578125 ,  18.5546875,
#          19.53125  ,  20.5078125,  21.484375 ,  22.4609375,  23.4375   ,
#          24.4140625,  25.390625 ,  26.3671875,  27.34375  ,  28.3203125,
#          29.296875 ,  30.2734375,  31.25     ,  32.2265625,  33.203125 ,
#          34.1796875,  35.15625  ,  36.1328125,  37.109375 ,  38.0859375,
#          39.0625   ,  40.0390625,  41.015625 ,  41.9921875,  42.96875  ,
#          43.9453125,  44.921875 ,  45.8984375,  46.875    ,  47.8515625,
#          48.828125 ,  49.8046875,  50.78125  ,  51.7578125,  52.734375 ,
#          53.7109375,  54.6875   ,  55.6640625,  56.640625 ,  57.6171875,
#          58.59375  ,  59.5703125,  60.546875 ,  61.5234375,  62.5      ,
# ...

# %%
https://github.com/gerazov/EEGpy/blob/master/eeg_coherence_master.py
    
    
    https://github.com/mateuspedrino/EEG-real-time-acquisition-and-power-spectrum-and-coherence-analysis/tree/master/data_analysis
        https://github.com/Eden-Kramer-Lab/spectral_connectivity/blob/master/spectral_connectivity/connectivity.py
